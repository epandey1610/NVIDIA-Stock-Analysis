# %%
import pandas as pd

import yfinance as yf

# %%
nvda = yf.Ticker("NVDA")

# %%
nvda = nvda.history( period = "max")

# %%
nvda
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1999-01-22 00:00:00-05:00    0.040122    0.044779    0.035585    0.037615
# 1999-01-25 00:00:00-05:00    0.040600    0.042033    0.037615    0.041556
# 1999-01-26 00:00:00-05:00    0.042033    0.042869    0.037734    0.038331
# 1999-01-27 00:00:00-05:00    0.038451    0.039406    0.036301    0.038212
# 1999-01-28 00:00:00-05:00    0.038212    0.038451    0.037854    0.038092
# ...                               ...         ...         ...         ...
# 2025-01-17 00:00:00-05:00  136.690002  138.500000  135.460007  137.710007
# 2025-01-21 00:00:00-05:00  139.160004  141.830002  137.089996  140.830002
# 2025-01-22 00:00:00-05:00  144.660004  147.789993  143.669998  147.070007
# 2025-01-23 00:00:00-05:00  145.050003  147.229996  143.720001  147.220001
# 2025-01-24 00:00:00-05:00  148.369995  148.970001  141.880005  142.619995
#
#                                Volume  Dividends  Stock Splits
# Date
# ...

# %%
nvda.index
# Out:
# DatetimeIndex(['1999-01-22 00:00:00-05:00', '1999-01-25 00:00:00-05:00',
#                '1999-01-26 00:00:00-05:00', '1999-01-27 00:00:00-05:00',
#                '1999-01-28 00:00:00-05:00', '1999-01-29 00:00:00-05:00',
#                '1999-02-01 00:00:00-05:00', '1999-02-02 00:00:00-05:00',
#                '1999-02-03 00:00:00-05:00', '1999-02-04 00:00:00-05:00',
#                ...
#                '2025-01-10 00:00:00-05:00', '2025-01-13 00:00:00-05:00',
#                '2025-01-14 00:00:00-05:00', '2025-01-15 00:00:00-05:00',
#                '2025-01-16 00:00:00-05:00', '2025-01-17 00:00:00-05:00',
#                '2025-01-21 00:00:00-05:00', '2025-01-22 00:00:00-05:00',
#                '2025-01-23 00:00:00-05:00', '2025-01-24 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=6543, freq=None)

# %%
nvda.plot.line(y="Close", use_index = True)
# Out:
# <Axes: xlabel='Date'>

# %%
del nvda["Dividends"]

del nvda["Stock Splits"]

# %%
nvda.head()
# Out:
#                                Open      High       Low     Close      Volume
# Date
# 1999-01-22 00:00:00-05:00  0.040122  0.044779  0.035585  0.037615  2714688000
# 1999-01-25 00:00:00-05:00  0.040600  0.042033  0.037615  0.041556   510480000
# 1999-01-26 00:00:00-05:00  0.042033  0.042869  0.037734  0.038331   343200000
# 1999-01-27 00:00:00-05:00  0.038451  0.039406  0.036301  0.038212   244368000
# 1999-01-28 00:00:00-05:00  0.038212  0.038451  0.037854  0.038092   227520000

# %%
#checking data types and covert them to numerical form

print(nvda.dtypes)

# Convert relevant columns to numerical types
for col in ['Open', 'High', 'Low', 'Close', 'Volume']:
    nvda[col] = pd.to_numeric(nvda[col], errors='coerce')

nvda.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object

# %%
nvda["Tomorrow"] = nvda["Close"].shift(-1)

# %%
nvda.head()
# Out:
#                                Open      High       Low     Close      Volume  \
# Date
# 1999-01-22 00:00:00-05:00  0.040122  0.044779  0.035585  0.037615  2714688000
# 1999-01-25 00:00:00-05:00  0.040600  0.042033  0.037615  0.041556   510480000
# 1999-01-26 00:00:00-05:00  0.042033  0.042869  0.037734  0.038331   343200000
# 1999-01-27 00:00:00-05:00  0.038451  0.039406  0.036301  0.038212   244368000
# 1999-01-28 00:00:00-05:00  0.038212  0.038451  0.037854  0.038092   227520000
#
#                            Tomorrow
# Date
# 1999-01-22 00:00:00-05:00  0.041556
# 1999-01-25 00:00:00-05:00  0.038331
# 1999-01-26 00:00:00-05:00  0.038212
# 1999-01-27 00:00:00-05:00  0.038092
# 1999-01-28 00:00:00-05:00  0.036301

# %%
# Daily Price Change

nvda["Price_Change"] = nvda["High"] - nvda["Close"]

# %%
nvda.head()
# Out:
#                                Open      High       Low     Close      Volume  \
# Date
# 1999-01-22 00:00:00-05:00  0.040122  0.044779  0.035585  0.037615  2714688000
# 1999-01-25 00:00:00-05:00  0.040600  0.042033  0.037615  0.041556   510480000
# 1999-01-26 00:00:00-05:00  0.042033  0.042869  0.037734  0.038331   343200000
# 1999-01-27 00:00:00-05:00  0.038451  0.039406  0.036301  0.038212   244368000
# 1999-01-28 00:00:00-05:00  0.038212  0.038451  0.037854  0.038092   227520000
#
#                            Tomorrow  Price_Change
# Date
# 1999-01-22 00:00:00-05:00  0.041556      0.007164
# 1999-01-25 00:00:00-05:00  0.038331      0.000477
# 1999-01-26 00:00:00-05:00  0.038212      0.004538
# 1999-01-27 00:00:00-05:00  0.038092      0.001194
# 1999-01-28 00:00:00-05:00  0.036301      0.000359

# %%
# Now creating a Target

# Compare 'Tomorrow' with 'Close' and convert the boolean result to integers
nvda["Target"] = (nvda["Tomorrow"] > nvda["Close"]).astype(int)

# Verify the change
print(nvda["Target"].head())
# Out:
# Date
# 1999-01-22 00:00:00-05:00    1
# 1999-01-25 00:00:00-05:00    0
# 1999-01-26 00:00:00-05:00    0
# 1999-01-27 00:00:00-05:00    0
# 1999-01-28 00:00:00-05:00    0
# Name: Target, dtype: int64

# %%
nvda
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1999-01-22 00:00:00-05:00    0.040122    0.044779    0.035585    0.037615
# 1999-01-25 00:00:00-05:00    0.040600    0.042033    0.037615    0.041556
# 1999-01-26 00:00:00-05:00    0.042033    0.042869    0.037734    0.038331
# 1999-01-27 00:00:00-05:00    0.038451    0.039406    0.036301    0.038212
# 1999-01-28 00:00:00-05:00    0.038212    0.038451    0.037854    0.038092
# ...                               ...         ...         ...         ...
# 2025-01-17 00:00:00-05:00  136.690002  138.500000  135.460007  137.710007
# 2025-01-21 00:00:00-05:00  139.160004  141.830002  137.089996  140.830002
# 2025-01-22 00:00:00-05:00  144.660004  147.789993  143.669998  147.070007
# 2025-01-23 00:00:00-05:00  145.050003  147.229996  143.720001  147.220001
# 2025-01-24 00:00:00-05:00  148.369995  148.970001  141.880005  142.619995
#
#                                Volume    Tomorrow  Price_Change  Target
# ...

# %%
# Our data column is set under Date and Time so we would change as we don't look for hourly changes in stock as it could be for later.

# Reset the index to make "Date" a column

nvda.reset_index(inplace = True)

# Modifying the "Date" column to only include the date part

nvda["Date"] = nvda["Date"].dt.date

#Optionally, Setting the date column back to as the index

nvda.set_index("Date", inplace=True)

# %%
nvda
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 1999-01-22    0.040122    0.044779    0.035585    0.037615  2714688000
# 1999-01-25    0.040600    0.042033    0.037615    0.041556   510480000
# 1999-01-26    0.042033    0.042869    0.037734    0.038331   343200000
# 1999-01-27    0.038451    0.039406    0.036301    0.038212   244368000
# 1999-01-28    0.038212    0.038451    0.037854    0.038092   227520000
# ...                ...         ...         ...         ...         ...
# 2025-01-17  136.690002  138.500000  135.460007  137.710007   201188800
# 2025-01-21  139.160004  141.830002  137.089996  140.830002   197749000
# 2025-01-22  144.660004  147.789993  143.669998  147.070007   237651400
# 2025-01-23  145.050003  147.229996  143.720001  147.220001   155915500
# 2025-01-24  148.369995  148.970001  141.880005  142.619995   233818600
#
#               Tomorrow  Price_Change  Target
# Date
# 1999-01-22    0.041556      0.007164       1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = nvda.iloc[:-100]
test = nvda.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low", "Price_Change"]

model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
preds = pd.Series(preds, index=test.index)

# %%
preds
# Out:
# Date
# 2024-08-30    1
# 2024-09-03    1
# 2024-09-04    1
# 2024-09-05    1
# 2024-09-06    1
#              ..
# 2025-01-17    0
# 2025-01-21    0
# 2025-01-22    0
# 2025-01-23    0
# 2025-01-24    0
# Length: 100, dtype: int64

# %%
precision_score(test["Target"], preds)
# Out:
# 0.6521739130434783

# %%
combined = pd.concat([test["Target"], preds], axis = 1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#creating Back testing loop

def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
# Every year has 250 trading days,therefore, 250*10=2500
# Which suggests a decade long data

def backtest(data, model, predictors, start=2500, step=250):
  all_predictions = []
  for i in range(start, data.shape[0],step):
    train = data.iloc[0:i].copy()
    test = data.iloc[i:(i+step)].copy()
    predictions = predict(train, test, predictors, model)
    all_predictions.append(predictions)

  return pd.concat(all_predictions)

# %%
predictions = backtest(nvda, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    2222
# 1    1821
# Name: count, dtype: int64

# %%
# 0 = Suggesting market would go down  for 2222 days

# 1 = Suggesting market would go up for 1821 days

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5304777594728172

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.529805
# 0    0.470195
# Name: count, dtype: float64

# %%
# Accuracy is poor again
# Hence, we will use rolling Averages

horizions = [2,5,60,250,1000]
new_predictors = []

for horizion in horizions:
  rolling_averages = nvda.rolling(horizion).mean()

  ratio_column = f"Close_Ratio_{horizion}"
  nvda[ratio_column] = nvda["Close"] / rolling_averages["Close"]
  new_predictors.append(ratio_column)

  trend_column = f"Trend_{horizion}"
  nvda[trend_column] = nvda.shift(1).rolling(horizion).sum()["Target"]
  new_predictors.append(trend_column)

  new_predictors += [ratio_column, trend_column]

# %%
nvda.head()
# Out:
#                 Open      High       Low     Close      Volume  Tomorrow  \
# Date
# 1999-01-22  0.040122  0.044779  0.035585  0.037615  2714688000  0.041556
# 1999-01-25  0.040600  0.042033  0.037615  0.041556   510480000  0.038331
# 1999-01-26  0.042033  0.042869  0.037734  0.038331   343200000  0.038212
# 1999-01-27  0.038451  0.039406  0.036301  0.038212   244368000  0.038092
# 1999-01-28  0.038212  0.038451  0.037854  0.038092   227520000  0.036301
#
#             Price_Change  Target  Close_Ratio_2  Trend_2  Close_Ratio_5  \
# Date
# 1999-01-22      0.007164       1            NaN      NaN            NaN
# 1999-01-25      0.000477       0       1.049775      NaN            NaN
# 1999-01-26      0.004538       0       0.959637      1.0            NaN
# 1999-01-27      0.001194       0       0.998443      0.0            NaN
# 1999-01-28      0.000359       0       0.998425      0.0       0.982733
#
#             Trend_5  Close_Ratio_60  Trend_60  Close_Ratio_250  Trend_250  \
# ...

# %%
# Removing Nan

nvda = nvda.dropna()

nvda
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 2003-01-15    0.094536    0.095301    0.091555    0.091555   904584000
# 2003-01-16    0.090180    0.091326    0.084143    0.085365  2039976000
# 2003-01-17    0.083072    0.084219    0.081086    0.082155  1058832000
# 2003-01-21    0.083684    0.085442    0.079863    0.080092   967356000
# 2003-01-22    0.079863    0.082232    0.079633    0.080169   550992000
# ...                ...         ...         ...         ...         ...
# 2025-01-16  138.639999  138.750000  133.490005  133.570007   209235600
# 2025-01-17  136.690002  138.500000  135.460007  137.710007   201188800
# 2025-01-21  139.160004  141.830002  137.089996  140.830002   197749000
# 2025-01-22  144.660004  147.789993  143.669998  147.070007   237651400
# 2025-01-23  145.050003  147.229996  143.720001  147.220001   155915500
#
#               Tomorrow  Price_Change  Target  Close_Ratio_2  Trend_2  \
# Date
# ...

# %%
# Updating the model

model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
# Adjusting the prediction filter

def predict(train, test, predictors, model):
  model.fit(train[predictors], train["Target"])
  preds = model.predict_proba(test[predictors])[:,1]
  preds[preds >= .6] = 1
  preds[preds < .6] = 0
  preds = pd.Series(preds, index=test.index, name="Predictions")
  combined = pd.concat([test["Target"], preds], axis=1)
  return combined

# %%
predictions = backtest(nvda, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    2743
# 1.0     299
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5785953177257525
